# %%
import numpy as np
import torch
from python.utils.plot import Plotter

file_name = "saves/cGan_100_v/logs/"

early_stop = -1

# %%
plotter = Plotter(file_name, early_stop)
plotter.discriminant_loss_plot(R1=False)

# %%
plotter.generator_loss_plot()

# %%
plotter.evaluation()

# %%
plotter.cGan_plot()

# %%
plotter.L1_loss_plot()
