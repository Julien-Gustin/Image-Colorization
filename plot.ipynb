# %%
import numpy as np
import torch
from python.utils.plot import Plotter

file_name = "saves/ES_100_30x30_R1/logs/"

early_stop = 17

# %%
plotter = Plotter(file_name, early_stop)
plotter.discriminant_loss_plot()

# %%
plotter.generator_loss_plot()

# %%
plotter.evaluation()

# %%
plotter.cGan_plot()

# %%
plotter.L1_loss_plot()
